# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline
recent_grads= pd.read_csv('recent-grads.csv', encoding= 'Latin-1')
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
recent_grads.info()
raw_data_count= 173
recent_grads= recent_grads.dropna()
recent_grads.info()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# after dropping the rows containig null values we only lose 1 row.

# %% [markdown]
# # generating scatter plot

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y= 'Unemployment_rate', kind= 'scatter')

# %%
recent_grads.plot(x= 'Full_time', y= 'Median', kind= 'scatter')

# %% [markdown]
# Is there any link between the number of full-time employees and median salary?
#
# i didnt understand the value that "full time "column contains.looking for your answer please.

# %%
recent_grads.plot(x= 'ShareWomen', y ='Unemployment_rate',kind='scatter')

# %%
recent_grads.plot(x= 'Men', y ='Median',kind='scatter')

# %%
recent_grads.plot(x= 'Women', y ='Median',kind='scatter')

# %%
recent_grads.plot(x='Total', y='Median', kind='scatter')

# %% [markdown]
# Do students in more popular majors make more money?
#
# from the above scatter plots(total vs median)it is sure that student in more popular major do no make more money. instead of making more money the are earning comperatively low money.

# %%
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter')

# %% [markdown]
# Do students that majored in subjects that were majority female make more money?
#
# students that majored in subjects that were majority female doesnot make more money but less mejority female of a majored
# makes more money

# %% [markdown]
# # Generating histogram

# %%
recent_grads['Sample_size'].hist(bins=40, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=15, range=(22000,110000))
pd.cut(recent_grads['Median'], bins=10).value_counts()
# Out:
# (21911.999, 30800.0]    24
# (30800.0, 39600.0]      75
# (39600.0, 48400.0]      40
# (48400.0, 57200.0]      18
# (57200.0, 66000.0]      11
# (66000.0, 74800.0]       2
# (74800.0, 83600.0]       1
# (83600.0, 92400.0]       0
# (92400.0, 101200.0]      0
# (101200.0, 110000.0]     1
# Name: Median, dtype: int64

# %% [markdown]
# What's the most common median salary range?
#
# the most common range of median is 30800-39600.

# %%
recent_grads['Employed'].hist(bins=50, range=(0,310000))

# %%
recent_grads['Full_time'].hist(bins=50, range=(100,252000))

# %%
recent_grads['ShareWomen'].hist(bins=50, range=(0,1))
recent_grads['ShareWomen'].value_counts(bins=10).sort_index()
# Out:
# (-0.0019690000000000003, 0.0969]     3
# (0.0969, 0.194]                     14
# (0.194, 0.291]                      16
# (0.291, 0.388]                      22
# (0.388, 0.484]                      19
# (0.484, 0.581]                      21
# (0.581, 0.678]                      25
# (0.678, 0.775]                      29
# (0.775, 0.872]                      11
# (0.872, 0.969]                      12
# Name: ShareWomen, dtype: int64

# %% [markdown]
# What percent of majors are predominantly female?
#
# from above figure , 97 majors among the 172 are predominantly female as there percentage is abobe 50%.
# so percent of majors that are predominantly female is (97/172)*100 = 56.39 %
#
# what percent of majors are predominantly male?
#
# percent of majors that are predominantly male is (100-56.39) = 43.61 %

# %%
recent_grads['Unemployment_rate'].hist(bins=50, range=(0,0.2))

# %%
recent_grads['Men'].hist(bins=50, range=(100,174000))

# %%
recent_grads['Women'].hist(bins=50, range=(0,308000))

# %% [markdown]
# # Generating scatter matrix

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EEA42C0348>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EEA38A4B48>,
# ...
#       dtype=object)

# %% [markdown]
# # Generating bar plots

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# from the above figure it seems that women are more interested in 'ASTRONOMY AND ASTROPHYSICS' and a few female students are interested in 'MINING AND MINERAL ENGINEERING' AND 'NAVAL ARCHITECTURE AND MARINE ENGINEERING'

# %%
recent_grads[163:].plot.bar(x= 'Major', y= 'ShareWomen')

# %% [markdown]
# from the above figure it seems that women are more interested in 'EARLY CHILDHOOD EDUCATION' Major.

# %%
recent_grads[:10].plot.bar(x='Major',y='Unemployment_rate')

# %% [markdown]
# students of 'NUCLEAR ENGINEERING' have higher unemployment rate. and students of 'PETROLIUM ENGINEERING' are highly employed

# %%
recent_grads[163:].plot.bar(x='Major',y='Unemployment_rate')

# %%
from above figure "CLINICAL PSYCHOLOGY " students are also unemployed than other majors.
